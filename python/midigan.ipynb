# %%
import csv
with open('output.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    rows = list(readCSV)

# %%
import os
os.getcwd()
# Out:
# '/Users/emilyxie/Projects/jazz-generator'

# %%
def remove_spaces(arr):
    for row in range(len(arr)):
        for r in range(len(arr[row])):
            arr[row][r] = arr[row][r].strip()
    return arr

# %%
def getNote(num):
    noteNum = num - 40
    return note_map[noteNum]

note_map = []
ascii_val = 48
for i in range(50):
    note_map.append(chr(ascii_val))
    ascii_val += 1

# %%
def round_to_nearest_6(num):
    n = num + (6//2)
    return n - (n % 6)

# %%
getNote(61)
# Out:
# 'E'

# %%
def add_data(row, nextRow, nextNote, endpt):
    time = (nextNote[1] - row[1]) / 40
    #print("time:" + str(time))
    #hyphens = "-" * int(time)
    note = getNote(row[4])
    #print("note:" + str(note))
    if check_for_rests(row, nextRow, nextNote) == True:
        print("checking for rests")
        if nextNote[1] > endpt:
            print("nah it's normal")
            return note * int(time) + "\n"
        else:
            print('rest processing')
            rests = int((nextNote[1] - nextRow[1]) / 40) - 1
            rests = round_to_nearest_6(rests)
            new_note_length = int((nextRow[1] - row[1]) / 40) + 1
            new_note_length = round_to_nearest_6(new_note_length)
            print('rest and new note length: ' + str(rests) + ',' + str(new_note_length))
            return note * new_note_length + "\n" + '-' * rests + "\n"
    return note * int(time) + "\n"

# %%
def check_for_rests(row, nextRow, nextNote):
    if nextNote[1] - nextRow[1] >= 40:
        return True
    else:
        return False

# %% [raw]
# rows[50]

# %%
rows[51]
# Out:
# ['1', ' 4787', ' Note_on_c', ' 0', ' 55', ' 0']

# %%
rows[51][5].strip()
# Out:
# '0'

# %%
noSpaces = remove_spaces(rows)

# %%
#noSpaces

# %%
type(noSpaces[0][2])
# Out:
# str

# %%
def strToInt(arr):
    for row in range(len(arr)):
        for r in range(len(arr[row])):
            try:
                arr[row][r] = int(arr[row][r])
            except(ValueError):
                pass
    return arr

# %%
def getNote(num):
    noteNum = num - 40
    return note_map[noteNum]

note_map = []
ascii_val = 48
for i in range(50):
    note_map.append(chr(ascii_val))
    ascii_val += 1

# %%
getNote(0)
# Out:
# ':'

# %%
endpt = 0
measure = 0
HERE = os.getcwd()
FILE_PATH = HERE + "/cmaj-gan-measures/"
FILE_BASE = "cmaj-measure"
noSpaces = remove_spaces(rows)
formatted = strToInt(noSpaces)
#print(formatted)

# %%
def add_rest(prev, row):
    time = int((row - prev) / 40)
    print('rest time: ' + str(time))
    return "-" * time + "\n"

# %%
endpt = 0
measure = 0
print("first endpt: " + str(endpt))
for row in range(len(formatted)):
    if formatted[row][2] != 'Note_on_c' or formatted[row][5] != 80:
        continue
    if formatted[row][1] == endpt: #endpt is actually startpt of a new measure
        try:
            measure += 1
            #f = open(FILE_PATH + FILE_BASE + str(measure), 'a')
            print("measure:" + str(measure))
            endpt = endpt + 1920
            print("endpt 1:" + str(endpt))
            added_data = add_data(formatted[row], formatted[row+1], formatted[row+2], endpt)
            print("added data: " + added_data)
            #f.write(add_data(formatted[row], formatted[row+2]))
            #f.close()
            continue
        except(IndexError):
            #print(IndexError)
            pass
    if formatted[row][1] > endpt:
        try:
            measure += 1
            print('measure: ' + str(measure))
            endpt = endpt + 1920 * 2
            prev_endpt = endpt - 1920
            if formatted[row][1] == prev_endpt:
                print('endpt: ' + str(endpt))
                added_data = add_data(formatted[row], formatted[row+1], formatted[row+2], endpt)
                print('added data: ' + added_data)
            else:
                rests = add_rest(prev_endpt, formatted[row][1])
                note = add_data(formatted[row], formatted[row+1], formatted[row+2], endpt)
                added_data = rests + note
                print('added data:' + added_data)
            continue
        except(IndexError):
            pass
    if formatted[row][1] < endpt:
        try:
            print("endpt 2:" + str(endpt))
            #print("measure:" + str(measure))
            #f = open(FILE_PATH + FILE_BASE + str(measure), 'a')
            added_data = add_data(formatted[row], formatted[row+1], formatted[row+2], endpt)
            print("added data: " + added_data)
            #f.write(add_data(formatted[row], formatted[row+2]))
            #f.close()
            continue
        except(IndexError):
            #print(IndexError)
            pass
# Out:
# first endpt: 0
# measure:1
# endpt 1:1920
# added data: TTTTTT
#
# endpt 2:1920
# added data: RRRRRR
#
# endpt 2:1920
# added data: PPPPPP
#
# endpt 2:1920
# added data: OOOOOO
#
# endpt 2:1920
# added data: RRRRRR
#
# endpt 2:1920
# added data: PPPPPP
#
# endpt 2:1920
# added data: OOOOOO
#
# endpt 2:1920
# added data: MMMMMM
#
# measure:2
# endpt 1:3840
# added data: KKKKKK
#
# endpt 2:3840
# added data: HHHHHH
#
# endpt 2:3840
# added data: IIIIII
#
# endpt 2:3840
# added data: MMMMMM
#
# endpt 2:3840
# added data: KKKKKK
#
# endpt 2:3840
# added data: CCCCCC
#
# endpt 2:3840
# added data: DDDDDD
#
# endpt 2:3840
# added data: IIIIII
#
# measure:3
# endpt 1:5760
# added data: HHHHHH
#
# endpt 2:5760
# added data: DDDDDD
#
# endpt 2:5760
# added data: AAAAAA
#
# endpt 2:5760
# added data: ??????
#
# endpt 2:5760
# checking for rests
# nah it's normal
# added data: DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD
#
# measure: 4
# endpt: 9600
# added data: HHHHHH
#
# endpt 2:9600
# added data: IIIIII
#
# endpt 2:9600
# added data: KKKKKK
#
# endpt 2:9600
# added data: MMMMMM
#
# endpt 2:9600
# added data: KKKKKK
#
# endpt 2:9600
# added data: MMMMMM
#
# endpt 2:9600
# added data: OOOOOO
#
# endpt 2:9600
# added data: PPPPPP
#
# measure:5
# endpt 1:11520
# added data: RRRRRR
#
# endpt 2:11520
# added data: TTTTTT
#
# endpt 2:11520
# added data: UUUUUU
#
# endpt 2:11520
# added data: RRRRRR
#
# endpt 2:11520
# added data: TTTTTT
#
# endpt 2:11520
# added data: PPPPPP
#
# endpt 2:11520
# added data: MMMMMM
#
# endpt 2:11520
# added data: KKKKKK
#
# measure:6
# endpt 1:13440
# added data: IIIIII
#
# endpt 2:13440
# added data: MMMMMM
#
# endpt 2:13440
# added data: PPPPPP
#
# endpt 2:13440
# added data: MMMMMM
#
# endpt 2:13440
# added data: OOOOOO
#
# endpt 2:13440
# added data: KKKKKK
#
# endpt 2:13440
# added data: HHHHHH
#
# endpt 2:13440
# checking for rests
# nah it's normal
# added data: DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD
#
# measure: 7
# rest time: 18
# added data:------------------
# TTTTTT
#
# endpt 2:17280
# added data: WWWWWW
#
# endpt 2:17280
# added data: TTTTTT
#
# endpt 2:17280
# added data: RRRRRR
#
# endpt 2:17280
# added data: PPPPPP
#
# measure:8
# endpt 1:19200
# added data: RRRRRRRRRRRRRRRRRR
#
# endpt 2:19200
# added data: RRRRRR
#
# endpt 2:19200
# added data: UUUUUU
#
# endpt 2:19200
# added data: RRRRRR
#
# endpt 2:19200
# added data: PPPPPP
#
# endpt 2:19200
# added data: OOOOOO
#
# measure:9
# endpt 1:21120
# added data: PPPPPPPPPPPPPPPPPP
#
# endpt 2:21120
# added data: PPPPPP
#
# endpt 2:21120
# added data: TTTTTT
#
# endpt 2:21120
# added data: PPPPPP
#
# endpt 2:21120
# added data: OOOOOO
#
# endpt 2:21120
# added data: MMMMMM
#
# measure:10
# endpt 1:23040
# added data: KKKKKK
#
# endpt 2:23040
# added data: MMMMMM
#
# endpt 2:23040
# added data: HHHHHH
#
# endpt 2:23040
# added data: IIIIII
#
# endpt 2:23040
# added data: KKKKKK
#
# endpt 2:23040
# added data: HHHHHH
#
# endpt 2:23040
# added data: IIIIII
#
# endpt 2:23040
# added data: KKKKKK
#
# measure:11
# endpt 1:24960
# added data: TTTTTT
#
# endpt 2:24960
# added data: PPPPPP
#
# endpt 2:24960
# added data: MMMMMM
#
# endpt 2:24960
# added data: IIIIII
#
# endpt 2:24960
# added data: HHHHHH
#
# endpt 2:24960
# added data: KKKKKK
#
# endpt 2:24960
# added data: OOOOOO
#
# endpt 2:24960
# added data: RRRRRR
#
# measure:12
# endpt 1:26880
# added data: PPPPPP
#
# endpt 2:26880
# added data: MMMMMM
#
# endpt 2:26880
# added data: IIIIII
#
# endpt 2:26880
# added data: FFFFFF
#
# endpt 2:26880
# added data: DDDDDD
#
# endpt 2:26880
# added data: HHHHHH
#
# endpt 2:26880
# added data: KKKKKK
#
# endpt 2:26880
# added data: OOOOOO
#
# measure:13
# endpt 1:28800
# added data: MMMMMM
#
# endpt 2:28800
# added data: KKKKKK
#
# endpt 2:28800
# added data: IIIIII
#
# endpt 2:28800
# added data: FFFFFF
#
# endpt 2:28800
# added data: HHHHHH
#
# endpt 2:28800
# added data: FFFFFF
#
# endpt 2:28800
# added data: DDDDDD
#
# endpt 2:28800
# added data: AAAAAA
#
# measure:14
# endpt 1:30720
# checking for rests
# rest processing
# rest and new note length: 24,24
# added data: ????????????????????????
# ------------------------
#
# measure:15
# endpt 1:32640
# added data: WWWWWW
#
# endpt 2:32640
# added data: TTTTTT
#
# endpt 2:32640
# added data: UUUU
#
# endpt 2:32640
# added data: WWWW
#
# endpt 2:32640
# added data: UUUU
#
# endpt 2:32640
# added data: TTTTTT
#
# endpt 2:32640
# added data: PPPPPP
#
# endpt 2:32640
# added data: MMMMMM
#
# endpt 2:32640
# added data: KKKKKK
#
# measure:16
# endpt 1:34560
# added data: PPPPPPPPPPPP
#
# endpt 2:34560
# added data: PPPPPP
#
# endpt 2:34560
# checking for rests
# rest processing
# rest and new note length: 18,6
# added data: TTTTTT
# ------------------
#
# endpt 2:34560
# added data: PPPPPP
#
# measure:17
# endpt 1:36480
# added data: YYYYYY
#
# endpt 2:36480
# added data: WWWWWW
#
# endpt 2:36480
# added data: OOOOOO
#
# endpt 2:36480
# added data: PPPPPP
#
# endpt 2:36480
# added data: UUUUUU
#
# endpt 2:36480
# added data: TTTTTT
#
# endpt 2:36480
# added data: KKKKKK
#
# endpt 2:36480
# added data: MMMMMM
#
# measure:18
# endpt 1:38400
# added data: OOOOOO
#
# endpt 2:38400
# added data: KKKKKK
#
# endpt 2:38400
# added data: HHHHHH
#
# endpt 2:38400
# added data: FFFFFF
#
# endpt 2:38400
# checking for rests
# rest processing
# rest and new note length: 0,24
# added data: FFFFFFFFFFFFFFFFFFFFFFFF
#
#
# measure:19
# endpt 1:40320
# added data: OOOOOO
#
# endpt 2:40320
# added data: PPPPPP
#
# endpt 2:40320
# added data: UUUUUU
#
# endpt 2:40320
# added data: RRRRRR
#
# endpt 2:40320
# added data: TTTTTT
#
# endpt 2:40320
# added data: PPPPPP
#
# endpt 2:40320
# added data: MMMMMM
#
# endpt 2:40320
# added data: KKKKKK
#
# measure:20
# endpt 1:42240
# added data: HHHHHH
#
# endpt 2:42240
# added data: IIIIII
#
# endpt 2:42240
# added data: MMMMMM
#
# endpt 2:42240
# added data: IIIIII
#
# endpt 2:42240
# added data: KKKKKK
#
# endpt 2:42240
# added data: HHHHHH
#
# endpt 2:42240
# added data: FFFFFF
#
# endpt 2:42240
# added data: DDDDDD
#
# measure:21
# endpt 1:44160
# added data: CCCCCC
#
# endpt 2:44160
# added data: DDDDDD
#
# endpt 2:44160
# added data: IIIIII
#
# endpt 2:44160
# added data: FFFFFF
#
# endpt 2:44160
# added data: HHHHHH
#
# endpt 2:44160
# added data: KKKKKK
#
# endpt 2:44160
# added data: OOOOOO
#
# endpt 2:44160
# added data: RRRRRR
#
# measure:22
# endpt 1:46080
# checking for rests
# rest processing
# rest and new note length: 0,48
# added data: RRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
#
#
# measure:23
# endpt 1:48000
# added data: PPPPPP
#
# endpt 2:48000
# added data: PPPPPP
#
# endpt 2:48000
# added data: MMMMMM
#
# endpt 2:48000
# added data: PPPPPP
#
# endpt 2:48000
# added data: OOOOOO
#
# endpt 2:48000
# added data: KKKKKK
#
# endpt 2:48000
# added data: HHHHHHHHHHHH
#
# measure:24
# endpt 1:49920
# added data: IIIIIIIIIIII
#
# endpt 2:49920
# added data: MMMMMM
#
# endpt 2:49920
# checking for rests
# rest processing
# rest and new note length: 24,6
# added data: KKKKKK
# ------------------------
#
# measure:25
# endpt 1:51840
# added data: IIIIII
#
# endpt 2:51840
# added data: IIIIII
#
# endpt 2:51840
# added data: FFFFFF
#
# endpt 2:51840
# added data: IIIIII
#
# endpt 2:51840
# added data: HHHHHH
#
# endpt 2:51840
# added data: DDDDDD
#
# endpt 2:51840
# added data: AAAAAAAAAAAA
#
# measure:26
# endpt 1:53760
# added data: ??????
#
# endpt 2:53760
# added data: AAAAAA
#
# endpt 2:53760
# added data: FFFFFF
#
# endpt 2:53760
# checking for rests
# rest processing
# rest and new note length: 24,6
# added data: DDDDDD
# ------------------------
#
# measure:27
# endpt 1:55680
# added data: TTTTTT
#
# endpt 2:55680
# checking for rests
# rest processing
# rest and new note length: 6,6
# added data: OOOOOO
# ------
#
# endpt 2:55680
# added data: RRRRRR
#
# endpt 2:55680
# checking for rests
# rest processing
# rest and new note length: 0,24
# added data: PPPPPPPPPPPPPPPPPPPPPPPP
#
#
# measure:28
# endpt 1:57600
# added data: RRRRRR
#
# endpt 2:57600
# checking for rests
# rest processing
# rest and new note length: 6,6
# added data: MMMMMM
# ------
#
# endpt 2:57600
# added data: PPPPPP
#
# endpt 2:57600
# checking for rests
# rest processing
# rest and new note length: 0,24
# added data: OOOOOOOOOOOOOOOOOOOOOOOO
#
#
# measure:29
# endpt 1:59520
# added data: PPPPPPPPPPPP
#
# endpt 2:59520
# added data: FFFF
#
# endpt 2:59520
# added data: HHHH
#
# endpt 2:59520
# added data: IIII
#
# endpt 2:59520
# added data: KKKKKK
#
# endpt 2:59520
# added data: MMMMMM
#
# endpt 2:59520
# added data: KKKKKK
#
# endpt 2:59520
# added data: IIIIII
#
# measure:30
# endpt 1:61440
# added data: HHHHHH
#
# endpt 2:61440
# added data: KKKKKK
#
# endpt 2:61440
# added data: MMMMMM
#
# endpt 2:61440
# added data: OOOOOO
#
# endpt 2:61440
# added data: OOOOOOOOOOOOOOOOOOOOOO
